# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# use print() to write your Name:

# %%
print("Shukri Alanbari")
# Out:
# Shukri Alanbari

# %% [markdown]
# use print() to write your E-Mail :

# %%
print("shokri.alanbari95@gmail.com")
# Out:
# shokri.alanbari95@gmail.com

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
subjects = {"mathematics", "biology"}
subjects.add("english")
print(subjects)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
text= "programming in python."
text.lower()
text.replace(" ","").replace(".","")
letters= set(text)
vowels= {"a", "e", "i", "o", "u"}
letters-= vowels
print("the number of items in the letters set is: ",len(letters))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a= {2, 4, 6, 8}
b= {4,10}
print(a^b)
# Out:
# {2, 6, 8, 10}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ad1_id= {"001", "002", "003"}
ad2_id= {"002", "003", "007"}
print(ad1_id^ad2_id)
# Out:
# {'001', '007'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
is_clicked= {"9001", "9002", "9005"}
is_bought= {"9002", "9004", "9005"}
Customer_id= set()
for id in is_clicked:
    if id in is_bought:
        Customer_id.add(id)
print(Customer_id)
# Out:
# {'9002', '9005'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dji1= ("AAPL.US", "IBM.US", "MSFT.US")
dji2= ("HD.US", "GS.US", "NKE.US")
print(dji1+dji2)
# Out:
# ('AAPL.US', 'IBM.US', 'MSFT.US', 'HD.US', 'GS.US', 'NKE.US')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dji1= ("AAPL.US", "IBM.US", "MSFT.US")
dji2= ("HD.US", "GS.US", "NKE.US")
print(dji1, dji2)
# Out:
# ('AAPL.US', 'IBM.US', 'MSFT.US') ('HD.US', 'GS.US', 'NKE.US')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
members= (("kate", 23), ("Tom", 19))
new_member= ("John", 26)
print (members[0], new_member, members[1])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
default= ("YES", "NO", "NO", "YES", "NO")
number_of_occurrences=(0)
for time in default:
    if time == "YES":
        number_of_occurrences+= 1
print (f"number of occurrences: ",number_of_occurrences)
# Out:
# number of occurrences:  2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
names = ("Monica", "Tom", "John", "Michael")
print(names[2], names[3], names[0], names[1] )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
info= (("Monica",19), ("Tom", 21), ("John", 18))
print(info[2], info[0], info[1])
print(info[1], info[0], info[2])
# Out:
# ('John', 18) ('Monica', 19) ('Tom', 21)
# ('Tom', 21) ('Monica', 19) ('John', 18)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stocks= (
    ("Apple Inc", ("AAPL.US", 310)),
    ("Microsoft Corp", ("MSFT.US", 184))
)
print(stocks[0][1][0])
# Out:
# AAPL.US

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cities= ["Los Angels", "New York", "Cicago"]
cities.append("Houston")
print (cities)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
idx= ("001", "002", "001", "003", "001")
number_of_occurrences=(0)
for time in idx:
    if time == "001":
        number_of_occurrences+= 1
print (f"number of occurrences: ",number_of_occurrences)
# Out:
# number of occurrences:  3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
text= "Python programming"
text.lower().replace(" ","")
unique= []
for char in text:
    if char not in unique:
        unique.append(char)
unique.sort()
print(unique)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
filenames= ["view.jpg", "bear.jpg", "ball.png"]
filenames.insert(0, "phonejpg")
filenames.remove("ball.png")
print(filenames)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
day1= ["3984", "9042", "4829", "2380"]
day2= ["4231", "5234", "1345", "2455"]
result= day1+day2
print(result)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
techs= ("python", "java", "sql", "aws")
lists= list(techs)
lists.sort()
print(lists)
# Out:
# ['aws', 'java', 'python', 'sql']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hashtags= ["summer", "time", "vibes"]
print(f"#{hashtags[0]}#{hashtags[1]}#{hashtags[2]}#")
# Out:
# #summer#time#vibes#

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dic=  {
    "USA": "Washington",
    "Germany": "Berlin",
    "Austria": "Vienna"
}
print(dic)
# Out:
# {'USA': 'Washington', 'Germany': 'Berlin', 'Austria': 'Vienna'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dic=  {
    "USA": "Washington",
    "Germany": "Berlin",
    "Austria": "Vienna"
}
keys= list(dic.keys())
print(keys)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dic=  {
    "USA": "Washington",
    "Germany": "Berlin",
    "Austria": "Vienna"
}
values= list(dic.values())
print(values)
# Out:
# ['Washington', 'Berlin', 'Vienna']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dic=  {
    "USA": "Washington",
    "Germany": "Berlin",
    "Austria": "Vienna"
}
keys= dic.items()
print(keys)
# Out:
# dict_items([('USA', 'Washington'), ('Germany', 'Berlin'), ('Austria', 'Vienna')])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dic=  {
    "USA": "Washington",
    "Germany": "Berlin",
    "Austria": "Vienna"
}
print(dic.get("Austria"))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stocks= {
    "MSFT.US": {"Microsoft Corp": 184},
    "AAPL.US": {"APPLE Inc":310},
    "MMM.US": {"3M CO": 148}
}
print(stocks.get("AAPL.US"))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stocks= {
    "MSFT.US": {"Microsoft Corp": 184},
    "AAPL.US": {"APPLE Inc":310},
    "MMM.US": {"3M CO": 148}
}
value= stocks["MSFT.US"]["Microsoft Corp"]
print (value)
# Out:
# 184

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stocks= {
    "MSFT.US": {"Microsoft Corp": 184},
    "AAPL.US": {"APPLE Inc":310},
    "MMM.US": {"3M CO": 148}
}
stocks["MSFT.US"]["Microsoft Corp"]= 190
print (stocks["MSFT.US"])
# Out:
# {'Microsoft Corp': 190}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stocks= {
    "MSFT.US": {"Microsoft Corp": 184},
    "AAPL.US": {"APPLE Inc":310},
    "MMM.US": {"3M CO": 148}
}
stocks["V.US"]= {"Visa Inc": 185}
print(stocks.values())
# Out:
# dict_values([{'Microsoft Corp': 184}, {'APPLE Inc': 310}, {'3M CO': 148}, {'Visa Inc': 185}])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
